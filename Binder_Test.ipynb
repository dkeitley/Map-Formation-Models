# %% [markdown]
# # Binder Test

# %%
import numpy
import matplotlib.pyplot as plt

# %%
print(1+1)
# Out:
# 2

# %%
def add(num1,num2):
    return num1+num2

# %%
add(5,2)
# Out:
# 7

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()
